# %% [markdown]
# <a href="https://colab.research.google.com/github/veerendra789/ai-mentor-portfolio/blob/main/Day1_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-genai

# %%
import os, getpass
os.environ['GEMINI_API_KEY'] = getpass.getpass('Paste your Google AI Studio key: ')
# Out:
# Paste your Google AI Studio key: ··········

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)
print(resp.text)
# Out:
# The 5-Layer AI Skill Pyramid outlines the essential components for successful AI implementation, from foundational data to strategic leadership:
#
# *   **Data Foundation:** The base layer involves robust data collection, cleaning, storage, and management, providing the raw material for any AI system.
# *   **Algorithms & Modeling:** This layer focuses on selecting, developing, and training machine learning models, statistical methods, and AI algorithms to process the data.
# *   **Domain Expertise:** Understanding the specific industry, problem context, and business needs to correctly frame problems and interpret AI outputs.
# *   **Application & Engineering:** The practical layer of deploying, integrating, scaling, and maintaining AI solutions within real-world systems and products (MLOps).
# *   **Strategic & Ethical Leadership:** The apex, guiding AI development with business strategy, ethical considerations, societal impact, and responsible governance.
